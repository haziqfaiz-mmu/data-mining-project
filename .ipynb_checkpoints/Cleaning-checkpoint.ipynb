# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from datetime import datetime

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#          Date      Time    Race  Gender Body_Size  Age_Range With_Kids  \
# 0  19/10/2015  20:17:50   malay    male  moderate       28.0       yes
# 1  19/10/2015  20:28:42     NaN    male      thin       32.0        no
# 2  19/10/2015  20:58:31   malay  female  moderate       30.0        no
# 3  19/10/2015  21:31:28  indian    male      thin       51.0        no
# 4  19/10/2015  21:40:28  indian    male       NaN       34.0        no
#
#   Kids_Category Basket_Size Basket_colour  ... Wash_Item Washer_No Dryer_No  \
# 0         young         big           red  ...   clothes         3       10
# 1       no_kids         big           NaN  ...       NaN         6        9
# 2       no_kids         big          blue  ...       NaN         4       10
# 3       no_kids         NaN         black  ...   clothes         5        9
# 4       no_kids         big          blue  ...   clothes         3        9
#
#   Spectacles TimeSpent_minutes buyDrinks  TotalSpent_RM  latitude   longitude  \
# 0         no              20.0       2.0            9.0  2.912316  101.657948
# 1         no              19.0       4.0           21.0  2.922506  101.643129
# 2         no              18.0       2.0           13.0  2.935533  101.737170
# 3         no              13.0       2.0           16.0  2.949924  101.637069
# 4        NaN              15.0       1.0           13.0  2.903530  101.661249
#
#    Num_of_Baskets
# 0             1.0
# 1             3.0
# 2             1.0
# 3             1.0
# 4             3.0
#
# [5 rows x 25 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)
df.dtypes
# Out:
# Date                 datetime64[ns]
# Time                         object
# Race                         object
# Gender                       object
# Body_Size                    object
# Age_Range                   float64
# With_Kids                    object
# Kids_Category                object
# Basket_Size                  object
# Basket_colour                object
# Attire                       object
# Shirt_Colour                 object
# shirt_type                   object
# Pants_Colour                 object
# pants_type                   object
# Wash_Item                    object
# Washer_No                     int64
# Dryer_No                      int64
# Spectacles                   object
# TimeSpent_minutes           float64
# buyDrinks                   float64
# TotalSpent_RM               float64
# latitude                    float64
# longitude                   float64
# Num_of_Baskets              float64
# dtype: object

# %%
df2 = df.select_dtypes(include=['object'])
df2.head()
# Out:
#        Time    Race  Gender Body_Size With_Kids Kids_Category Basket_Size  \
# 0  20:17:50   malay    male  moderate       yes         young         big
# 1  20:28:42     NaN    male      thin        no       no_kids         big
# 2  20:58:31   malay  female  moderate        no       no_kids         big
# 3  21:31:28  indian    male      thin        no       no_kids         NaN
# 4  21:40:28  indian    male       NaN        no       no_kids         big
#
#   Basket_colour  Attire Shirt_Colour    shirt_type Pants_Colour pants_type  \
# 0           red  casual         blue  short_sleeve        black      short
# 1           NaN  casual        white  short_sleeve   blue_jeans       long
# 2          blue  casual          red  short_sleeve        black       long
# 3         black  casual        black  short_sleeve       yellow      short
# 4          blue  casual         blue           NaN        white       long
#
#   Wash_Item Spectacles
# 0   clothes         no
# 1       NaN         no
# 2       NaN         no
# 3   clothes         no
# 4   clothes        NaN

# %%
for col in df2.columns:
    df2[col] = df[col].str.replace(' ','')
df2.head()
# Out:
#        Time    Race  Gender Body_Size With_Kids Kids_Category Basket_Size  \
# 0  20:17:50   malay    male  moderate       yes         young         big
# 1  20:28:42     NaN    male      thin        no       no_kids         big
# 2  20:58:31   malay  female  moderate        no       no_kids         big
# 3  21:31:28  indian    male      thin        no       no_kids         NaN
# 4  21:40:28  indian    male       NaN        no       no_kids         big
#
#   Basket_colour  Attire Shirt_Colour    shirt_type Pants_Colour pants_type  \
# 0           red  casual         blue  short_sleeve        black      short
# 1           NaN  casual        white  short_sleeve   blue_jeans       long
# 2          blue  casual          red  short_sleeve        black       long
# 3         black  casual        black  short_sleeve       yellow      short
# 4          blue  casual         blue           NaN        white       long
#
#   Wash_Item Spectacles
# 0   clothes         no
# 1       NaN         no
# 2       NaN         no
# 3   clothes         no
# 4   clothes        NaN

# %%
for col in df2.columns:
    df2[col] = df2[col].fillna(df2[col].mode()[0])
df2.head()
# Out:
#        Time    Race  Gender Body_Size With_Kids Kids_Category Basket_Size  \
# 0  20:17:50   malay    male  moderate       yes         young         big
# 1  20:28:42   malay    male      thin        no       no_kids         big
# 2  20:58:31   malay  female  moderate        no       no_kids         big
# 3  21:31:28  indian    male      thin        no       no_kids         big
# 4  21:40:28  indian    male  moderate        no       no_kids         big
#
#   Basket_colour  Attire Shirt_Colour    shirt_type Pants_Colour pants_type  \
# 0           red  casual         blue  short_sleeve        black      short
# 1         white  casual        white  short_sleeve   blue_jeans       long
# 2          blue  casual          red  short_sleeve        black       long
# 3         black  casual        black  short_sleeve       yellow      short
# 4          blue  casual         blue  short_sleeve        white       long
#
#   Wash_Item Spectacles
# 0   clothes         no
# 1   clothes         no
# 2   clothes         no
# 3   clothes         no
# 4   clothes         no

# %%
df3 = df.drop(df2.columns, axis=1)
df3.head()
# Out:
#         Date  Age_Range  Washer_No  Dryer_No  TimeSpent_minutes  buyDrinks  \
# 0 2015-10-19       28.0          3        10               20.0        2.0
# 1 2015-10-19       32.0          6         9               19.0        4.0
# 2 2015-10-19       30.0          4        10               18.0        2.0
# 3 2015-10-19       51.0          5         9               13.0        2.0
# 4 2015-10-19       34.0          3         9               15.0        1.0
#
#    TotalSpent_RM  latitude   longitude  Num_of_Baskets
# 0            9.0  2.912316  101.657948             1.0
# 1           21.0  2.922506  101.643129             3.0
# 2           13.0  2.935533  101.737170             1.0
# 3           16.0  2.949924  101.637069             1.0
# 4           13.0  2.903530  101.661249             3.0

# %%
for col in df3.columns:
    df3[col] = df3[col].fillna(df3[col].mean())
df3.head()
# Out:
#         Date  Age_Range  Washer_No  Dryer_No  TimeSpent_minutes  buyDrinks  \
# 0 2015-10-19       28.0          3        10               20.0        2.0
# 1 2015-10-19       32.0          6         9               19.0        4.0
# 2 2015-10-19       30.0          4        10               18.0        2.0
# 3 2015-10-19       51.0          5         9               13.0        2.0
# 4 2015-10-19       34.0          3         9               15.0        1.0
#
#    TotalSpent_RM  latitude   longitude  Num_of_Baskets
# 0            9.0  2.912316  101.657948             1.0
# 1           21.0  2.922506  101.643129             3.0
# 2           13.0  2.935533  101.737170             1.0
# 3           16.0  2.949924  101.637069             1.0
# 4           13.0  2.903530  101.661249             3.0

# %%
df_normalized = pd.DataFrame()

# %%
for col in df3.columns:
    if(col != "Date"):
        df_normalized[col] = stats.zscore(df3[col])
df_normalized.head()
# Out:
#    Age_Range  Washer_No  Dryer_No  TimeSpent_minutes  buyDrinks  \
# 0  -0.979143  -1.329343  1.383455          -1.095669  -0.306655
# 1  -0.635820   1.333782  0.483647          -1.165587   0.873818
# 2  -0.807481  -0.441635  1.383455          -1.235504  -0.306655
# 3   0.994965   0.446073  0.483647          -1.585093  -0.306655
# 4  -0.464158  -1.329343  0.483647          -1.445258  -0.896892
#
#    TotalSpent_RM  latitude  longitude  Num_of_Baskets
# 0      -1.175289 -1.974354   0.219731        -1.24844
# 1       1.620044 -1.844641   0.072282         1.25697
# 2      -0.243511 -1.678802   1.008022        -1.24844
# 3       0.455322 -1.495611   0.011978        -1.24844
# 4      -0.243511 -2.086209   0.252582         1.25697

# %%
df_normalized["Date"]=df3["Date"]
df_normalized.head()
# Out:
#    Age_Range  Washer_No  Dryer_No  TimeSpent_minutes  buyDrinks  \
# 0  -0.979143  -1.329343  1.383455          -1.095669  -0.306655
# 1  -0.635820   1.333782  0.483647          -1.165587   0.873818
# 2  -0.807481  -0.441635  1.383455          -1.235504  -0.306655
# 3   0.994965   0.446073  0.483647          -1.585093  -0.306655
# 4  -0.464158  -1.329343  0.483647          -1.445258  -0.896892
#
#    TotalSpent_RM  latitude  longitude  Num_of_Baskets       Date
# 0      -1.175289 -1.974354   0.219731        -1.24844 2015-10-19
# 1       1.620044 -1.844641   0.072282         1.25697 2015-10-19
# 2      -0.243511 -1.678802   1.008022        -1.24844 2015-10-19
# 3       0.455322 -1.495611   0.011978        -1.24844 2015-10-19
# 4      -0.243511 -2.086209   0.252582         1.25697 2015-10-19

# %%
df_normalized = pd.concat([df2,df_normalized],axis=1)
df_normalized.head()
# Out:
#        Time    Race  Gender Body_Size With_Kids Kids_Category Basket_Size  \
# 0  20:17:50   malay    male  moderate       yes         young         big
# 1  20:28:42   malay    male      thin        no       no_kids         big
# 2  20:58:31   malay  female  moderate        no       no_kids         big
# 3  21:31:28  indian    male      thin        no       no_kids         big
# 4  21:40:28  indian    male  moderate        no       no_kids         big
#
#   Basket_colour  Attire Shirt_Colour  ... Age_Range Washer_No  Dryer_No  \
# 0           red  casual         blue  ... -0.979143 -1.329343  1.383455
# 1         white  casual        white  ... -0.635820  1.333782  0.483647
# 2          blue  casual          red  ... -0.807481 -0.441635  1.383455
# 3         black  casual        black  ...  0.994965  0.446073  0.483647
# 4          blue  casual         blue  ... -0.464158 -1.329343  0.483647
#
#   TimeSpent_minutes buyDrinks  TotalSpent_RM  latitude  longitude  \
# 0         -1.095669 -0.306655      -1.175289 -1.974354   0.219731
# 1         -1.165587  0.873818       1.620044 -1.844641   0.072282
# 2         -1.235504 -0.306655      -0.243511 -1.678802   1.008022
# 3         -1.585093 -0.306655       0.455322 -1.495611   0.011978
# 4         -1.445258 -0.896892      -0.243511 -2.086209   0.252582
#
#    Num_of_Baskets       Date
# 0        -1.24844 2015-10-19
# 1         1.25697 2015-10-19
# 2        -1.24844 2015-10-19
# 3        -1.24844 2015-10-19
# 4         1.25697 2015-10-19
#
# [5 rows x 25 columns]

# %%
df = pd.concat([df2,df3],axis=1)
df.head()
# Out:
#        Time    Race  Gender Body_Size With_Kids Kids_Category Basket_Size  \
# 0  20:17:50   malay    male  moderate       yes         young         big
# 1  20:28:42   malay    male      thin        no       no_kids         big
# 2  20:58:31   malay  female  moderate        no       no_kids         big
# 3  21:31:28  indian    male      thin        no       no_kids         big
# 4  21:40:28  indian    male  moderate        no       no_kids         big
#
#   Basket_colour  Attire Shirt_Colour  ...       Date Age_Range Washer_No  \
# 0           red  casual         blue  ... 2015-10-19      28.0         3
# 1         white  casual        white  ... 2015-10-19      32.0         6
# 2          blue  casual          red  ... 2015-10-19      30.0         4
# 3         black  casual        black  ... 2015-10-19      51.0         5
# 4          blue  casual         blue  ... 2015-10-19      34.0         3
#
#   Dryer_No TimeSpent_minutes buyDrinks  TotalSpent_RM  latitude   longitude  \
# 0       10              20.0       2.0            9.0  2.912316  101.657948
# 1        9              19.0       4.0           21.0  2.922506  101.643129
# 2       10              18.0       2.0           13.0  2.935533  101.737170
# 3        9              13.0       2.0           16.0  2.949924  101.637069
# 4        9              15.0       1.0           13.0  2.903530  101.661249
#
#    Num_of_Baskets
# 0             1.0
# 1             3.0
# 2             1.0
# 3             1.0
# 4             3.0
#
# [5 rows x 25 columns]

# %%
weather = pd.read_csv("weather.csv")
weather.head()
# Out:
#                     name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Kuala Lumpur,Malaysia  2015-01-01     31.9     24.0  27.1          36.7
# 1  Kuala Lumpur,Malaysia  2015-01-02     31.7     24.0  26.7          37.4
# 2  Kuala Lumpur,Malaysia  2015-01-03     32.0     24.1  26.9          37.6
# 3  Kuala Lumpur,Malaysia  2015-01-04     31.5     24.0  27.1          36.2
# 4  Kuala Lumpur,Malaysia  2015-01-05     32.8     25.0  28.1          38.0
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          24.0       28.6  23.6      82.5  ...         13.1        6
# 1          24.0       28.0  23.1      81.6  ...         15.7        6
# 2          24.1       28.4  23.6      83.6  ...         17.1        7
# 3          24.0       29.4  23.4      81.3  ...         13.9        7
# 4          25.0       30.9  24.0      79.4  ...         12.7        5
#
#    severerisk              sunrise               sunset  moonphase  \
# 0         NaN  2015-01-01T07:18:16  2015-01-01T19:14:48       0.43
# 1         NaN  2015-01-02T07:18:43  2015-01-02T19:15:18       0.46
# 2         NaN  2015-01-03T07:19:09  2015-01-03T19:15:47       0.49
# 3         NaN  2015-01-04T07:19:36  2015-01-04T19:16:16       0.50
# 4         NaN  2015-01-05T07:20:01  2015-01-05T19:16:44       0.50
#
#                conditions                                        description  \
# 0          Rain, Overcast         Cloudy skies throughout the day with rain.
# 1  Rain, Partially cloudy        Partly cloudy throughout the day with rain.
# 2  Rain, Partially cloudy  Partly cloudy throughout the day with early mo...
# 3  Rain, Partially cloudy  Partly cloudy throughout the day with early mo...
# 4        Partially cloudy                  Partly cloudy throughout the day.
#
#                 icon                           stations
# 0               rain  48647099999,48650099999,WMSA,WMKK
# 1               rain  48647099999,48650099999,WMSA,WMKK
# 2               rain  48647099999,48650099999,WMSA,WMKK
# 3               rain  48647099999,48650099999,WMSA,WMKK
# 4  partly-cloudy-day  48647099999,48650099999,WMSA,WMKK
#
# [5 rows x 33 columns]

# %%
weather = weather[["datetime", "tempmax", "tempmin", "humidity","description", "icon"]]
weather.head()
# Out:
#      datetime  tempmax  tempmin  humidity  \
# 0  2015-01-01     31.9     24.0      82.5
# 1  2015-01-02     31.7     24.0      81.6
# 2  2015-01-03     32.0     24.1      83.6
# 3  2015-01-04     31.5     24.0      81.3
# 4  2015-01-05     32.8     25.0      79.4
#
#                                          description               icon
# 0         Cloudy skies throughout the day with rain.               rain
# 1        Partly cloudy throughout the day with rain.               rain
# 2  Partly cloudy throughout the day with early mo...               rain
# 3  Partly cloudy throughout the day with early mo...               rain
# 4                  Partly cloudy throughout the day.  partly-cloudy-day

# %%
weather.dtypes
# Out:
# datetime        object
# tempmax        float64
# tempmin        float64
# humidity       float64
# description     object
# icon            object
# dtype: object

# %%
weather['datetime'] = pd.to_datetime(weather['datetime'])
weather.dtypes
# Out:
# datetime       datetime64[ns]
# tempmax               float64
# tempmin               float64
# humidity              float64
# description            object
# icon                   object
# dtype: object

# %%
weather =weather.rename(columns = {'datetime':'Date'})
weather.head()
# Out:
#         Date  tempmax  tempmin  humidity  \
# 0 2015-01-01     31.9     24.0      82.5
# 1 2015-01-02     31.7     24.0      81.6
# 2 2015-01-03     32.0     24.1      83.6
# 3 2015-01-04     31.5     24.0      81.3
# 4 2015-01-05     32.8     25.0      79.4
#
#                                          description               icon
# 0         Cloudy skies throughout the day with rain.               rain
# 1        Partly cloudy throughout the day with rain.               rain
# 2  Partly cloudy throughout the day with early mo...               rain
# 3  Partly cloudy throughout the day with early mo...               rain
# 4                  Partly cloudy throughout the day.  partly-cloudy-day

# %%
merged_df = pd.merge(df, weather, on="Date")
merged_df.head()
# Out:
#        Time    Race  Gender Body_Size With_Kids Kids_Category Basket_Size  \
# 0  20:17:50   malay    male  moderate       yes         young         big
# 1  20:28:42   malay    male      thin        no       no_kids         big
# 2  20:58:31   malay  female  moderate        no       no_kids         big
# 3  21:31:28  indian    male      thin        no       no_kids         big
# 4  21:40:28  indian    male  moderate        no       no_kids         big
#
#   Basket_colour  Attire Shirt_Colour  ... buyDrinks TotalSpent_RM  latitude  \
# 0           red  casual         blue  ...       2.0           9.0  2.912316
# 1         white  casual        white  ...       4.0          21.0  2.922506
# 2          blue  casual          red  ...       2.0          13.0  2.935533
# 3         black  casual        black  ...       2.0          16.0  2.949924
# 4          blue  casual         blue  ...       1.0          13.0  2.903530
#
#     longitude Num_of_Baskets tempmax  tempmin  humidity  \
# 0  101.657948            1.0    31.9     26.1      81.6
# 1  101.643129            3.0    31.9     26.1      81.6
# 2  101.737170            1.0    31.9     26.1      81.6
# 3  101.637069            1.0    31.9     26.1      81.6
# 4  101.661249            3.0    31.9     26.1      81.6
#
#                         description    icon
# 0  Cloudy skies throughout the day.  cloudy
# 1  Cloudy skies throughout the day.  cloudy
# 2  Cloudy skies throughout the day.  cloudy
# 3  Cloudy skies throughout the day.  cloudy
# 4  Cloudy skies throughout the day.  cloudy
#
# [5 rows x 30 columns]

# %%
merged_df_normalized = pd.merge(df_normalized, weather, on="Date")
merged_df_normalized.head()
# Out:
#        Time    Race  Gender Body_Size With_Kids Kids_Category Basket_Size  \
# 0  20:17:50   malay    male  moderate       yes         young         big
# 1  20:28:42   malay    male      thin        no       no_kids         big
# 2  20:58:31   malay  female  moderate        no       no_kids         big
# 3  21:31:28  indian    male      thin        no       no_kids         big
# 4  21:40:28  indian    male  moderate        no       no_kids         big
#
#   Basket_colour  Attire Shirt_Colour  ... TotalSpent_RM  latitude longitude  \
# 0           red  casual         blue  ...     -1.175289 -1.974354  0.219731
# 1         white  casual        white  ...      1.620044 -1.844641  0.072282
# 2          blue  casual          red  ...     -0.243511 -1.678802  1.008022
# 3         black  casual        black  ...      0.455322 -1.495611  0.011978
# 4          blue  casual         blue  ...     -0.243511 -2.086209  0.252582
#
#   Num_of_Baskets       Date  tempmax  tempmin  humidity  \
# 0       -1.24844 2015-10-19     31.9     26.1      81.6
# 1        1.25697 2015-10-19     31.9     26.1      81.6
# 2       -1.24844 2015-10-19     31.9     26.1      81.6
# 3       -1.24844 2015-10-19     31.9     26.1      81.6
# 4        1.25697 2015-10-19     31.9     26.1      81.6
#
#                         description    icon
# 0  Cloudy skies throughout the day.  cloudy
# 1  Cloudy skies throughout the day.  cloudy
# 2  Cloudy skies throughout the day.  cloudy
# 3  Cloudy skies throughout the day.  cloudy
# 4  Cloudy skies throughout the day.  cloudy
#
# [5 rows x 30 columns]

# %%
merged_df.to_csv('merged.csv',index=False)

# %%
merged_df_normalized.to_csv('merged-normalized.csv',index=False)
